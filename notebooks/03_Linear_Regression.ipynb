# %% [markdown]
# # Importing Packages

# %%
import warnings
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.datasets import load_diabetes
from utils import *

warnings.simplefilter(action='ignore', category=Warning)

sns.set()

# %% [markdown]
# # Loading Data

# %%
# Load the diabetes dataset
data = load_diabetes()
X, y = data.data, data.target

# Get column names for features and target
feature_names = data.feature_names
target_names = ["target"]

# Combine feature matrix X and target vector y into a single DataFrame
df = pd.DataFrame(X, columns=feature_names)
df['target'] = y

# Display the DataFrame
print(df.head())
# Out:
#         age       sex       bmi        bp        s1        s2        s3
# 0  0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401  \
# 1 -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2  0.085299  0.050680  0.044451 -0.005670 -0.045599 -0.034194 -0.032356
# 3 -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4  0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
#
#          s4        s5        s6  target
# 0 -0.002592  0.019907 -0.017646   151.0
# 1 -0.039493 -0.068332 -0.092204    75.0
# 2 -0.002592  0.002861 -0.025930   141.0
# 3  0.034309  0.022688 -0.009362   206.0
# 4 -0.002592 -0.031988 -0.046641   135.0

# %% [markdown]
# Least Squares with Numpy

# %%
slope, intercept = np.polyfit(df['bmi'], df['target'], deg=1)

print('Slope: ', slope)
print('Intercept: ', intercept)
# Out:
# Slope:  949.4352603840236
# Intercept:  152.1334841628962

# %%
import numpy as np
import matplotlib.pyplot as plt

# Fit the polynomial regression line
slope, intercept = np.polyfit(df['bmi'], df['target'], deg=1)

# Scatter plot
plt.scatter(df['bmi'], df['target'], label='Data')

# Polynomial regression line
x = np.linspace(df['bmi'].min(), df['bmi'].max(), 100)
y = slope * x + intercept
plt.plot(x, y, color='red', label='Polyfit Line')

# Set labels and title
plt.xlabel('BMI')
plt.ylabel('Target')

# Annotation
equation = f'Target = {slope:.2f}BMI + {intercept:.2f}'
plt.annotate(
    equation,
    xy=(0.05, 0.95),
    xycoords='axes fraction',
    fontsize=12,
    ha='left',
    va='top',
    bbox=dict(boxstyle='round', fc='white', ec='gray', lw=1, alpha=0.7)
)


# Show the plot
plt.show()
